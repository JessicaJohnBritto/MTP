# %% [markdown]
# # <font color='red'>Definitions</font>

# %%
from pyblock2.driver.core import DMRGDriver, SymmetryTypes, MPOAlgorithmTypes
import numpy as np
import math
import matplotlib.pyplot as plt
import time

# %%
def vector_to_hermitian(upper_triangle_vector):
    # Check if the input vector is real-valued or complex-valued
    is_real = np.isrealobj(upper_triangle_vector)
    
    # Determine the size of the matrix (n x n)
    n = int(np.sqrt(2 * len(upper_triangle_vector) + 0.25) - 0.5)
    
    # Initialize an empty matrix with the appropriate type
    dtype = float if is_real else complex
    A = np.zeros((n, n), dtype=dtype)
    
    # Fill in the upper triangle
    indices = np.triu_indices(n)
    A[indices] = upper_triangle_vector
    
    # Assign values to the lower triangle
    i_lower = np.tril_indices(n, -1)
    if is_real:
        A[i_lower] = A.T[i_lower]  # Copy upper triangle values to lower triangle
    else:
        A[i_lower] = np.conj(A.T[i_lower])  # Assign conjugate transpose to lower triangle
    
    return A

# %% [markdown]
# # <font color='red'>Boson with $U/t = 10$</font>

# %% [markdown]
# ## <font color='blue'>Parameters</font>

# %%
L = 64
N = 64
t = 1.0
U = 10.0
nmax = 5

driver = DMRGDriver(scratch="./tmp", symm_type=SymmetryTypes.SAny, n_threads=4)

driver.set_symmetry_groups("U1")
Q = driver.bw.SX

# %% [markdown]
# ## <font color='blue'>Local operators</font>

# %%
# [Part A] Set states and matrix representation of operators in local Hilbert space
site_basis, site_ops = [], []

basis = [(Q(i), 1) for i in range(nmax + 1)]

bdag = np.diag([np.sqrt(n+1) for n in range(nmax)], -1)
b = bdag.T
ops = {
    "": np.identity(nmax + 1), 
    "c": bdag, 
    "d": b
}

#proj_keys = ["P"+str(n) for n in range(nmax+1)]
proj_keys = ["Q","R","S","T","U","V","W","X","Y"][:nmax+1]
proj_ops = []
for n in range(nmax+1):
    proj_diag = np.diag(np.repeat([0, 1., 0], [n, 1, nmax-n]))
    proj_ops.append(proj_diag)
proj_dict = {}
for n in range(nmax+1):
    proj_dict[proj_keys[n]] = proj_ops[n]

for k in range(L): 
    site_basis.append(basis)
    site_ops.append(ops | proj_dict)

# %% [markdown]
# ## <font color='blue'>Hamiltonian</font>

# %%
# [Part B] Set Hamiltonian terms
driver.initialize_system(n_sites=L, vacuum=Q(0), target=Q(N), hamil_init=False)
driver.ghamil = driver.get_custom_hamiltonian(site_basis, site_ops)
os = driver.expr_builder()

for i in range(L-1):
    os.add_term("cd", [i, i+1], -t)
    os.add_term("cd", [i+1, i], -t)
for i in range(L):
    os.add_term("ccdd", [i, i, i, i], U/2)

# [Part C] Perform DMRG
mpo = driver.get_mpo(os.finalize(adjust_order=True, fermionic_ops=""), algo_type=MPOAlgorithmTypes.FastBipartite)

# %% [markdown]
# ## <font color='blue'>DMRG</font>

# %%
mps = driver.get_random_mps(tag="KET", bond_dim=50, nroots=1, occs=[1] * L)
energy = driver.dmrg(
    mpo, 
    mps, 
    n_sweeps=100, 
    bond_dims=[50] * 10 + [100] * 5 + [200] * 5 + [500] * 5 + [1000] * 5, 
    noises=[1e-3] * 3 + [1e-5] * 3 + [0],  
    thrds=[1e-10] * 20, 
    dav_max_iter=100, 
    tol=1e-10, 
    iprint=1)
print("Final bond dimension =", mps.info.get_max_bond_dimension())
# Out:
# Sweep =    0 | Direction =  forward | Bond dimension =   50 | Noise =  1.00e-03 | Dav threshold =  1.00e-10
# Time elapsed =      1.389 | E =       4.5773130186 | DW = 5.00448e-12
#
# Sweep =    1 | Direction = backward | Bond dimension =   50 | Noise =  1.00e-03 | Dav threshold =  1.00e-10
# Time elapsed =      5.564 | E =      -9.3378641537 | DE = -1.39e+01 | DW = 8.81964e-11
#
# Sweep =    2 | Direction =  forward | Bond dimension =   50 | Noise =  1.00e-03 | Dav threshold =  1.00e-10
# Time elapsed =     12.484 | E =     -15.3346169939 | DE = -6.00e+00 | DW = 4.76560e-10
#
# Sweep =    3 | Direction = backward | Bond dimension =   50 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =     16.624 | E =     -24.8152812833 | DE = -9.48e+00 | DW = 1.69878e-11
#
# Sweep =    4 | Direction =  forward | Bond dimension =   50 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =     18.691 | E =     -24.9178072680 | DE = -1.03e-01 | DW = 2.00758e-15
#
# Sweep =    5 | Direction = backward | Bond dimension =   50 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =     20.123 | E =     -24.9178072682 | DE = -1.37e-10 | DW = 1.33349e-15
#
# Sweep =    6 | Direction =  forward | Bond dimension =   50 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =     21.063 | E =     -24.9178072682 | DE = 9.59e-14 | DW = 5.41724e-17
#
# Sweep =    7 | Direction = backward | Bond dimension =   50 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =     21.953 | E =     -24.9178072682 | DE = 1.46e-13 | DW = 1.15055e-16
#
# Sweep =    8 | Direction =  forward | Bond dimension =   50 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =     22.936 | E =     -24.9178072682 | DE = -1.42e-14 | DW = 3.51582e-17
#
# Sweep =    9 | Direction = backward | Bond dimension =   50 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =     23.888 | E =     -24.9178072682 | DE = -1.46e-13 | DW = 1.31902e-16
#
# Sweep =   10 | Direction =  forward | Bond dimension =  100 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =     26.505 | E =     -24.9178072682 | DE = -2.13e-14 | DW = 5.26344e-20
#
# Sweep =   11 | Direction = backward | Bond dimension =  100 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =     29.648 | E =     -24.9178072682 | DE = 1.10e-13 | DW = 5.58938e-20
#
# Sweep =   12 | Direction =  forward | Bond dimension =  100 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =     34.062 | E =     -24.9178072682 | DE = -7.11e-15 | DW = 6.08703e-20
#
# Sweep =   13 | Direction = backward | Bond dimension =  100 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =     39.909 | E =     -24.9178072682 | DE = -6.75e-14 | DW = 6.38930e-20
#
# Sweep =   14 | Direction =  forward | Bond dimension =  100 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =     45.717 | E =     -24.9178072682 | DE = 7.11e-15 | DW = 5.21455e-20
#
# Sweep =   15 | Direction = backward | Bond dimension =  200 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =     50.821 | E =     -24.9178072682 | DE = -3.55e-14 | DW = 6.22950e-20
#
# Sweep =   16 | Direction =  forward | Bond dimension =  200 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =     56.591 | E =     -24.9178072682 | DE = -3.55e-15 | DW = 5.16594e-20
#
# Sweep =   17 | Direction = backward | Bond dimension =  200 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =     61.373 | E =     -24.9178072682 | DE = 1.17e-13 | DW = 6.65489e-20
#
# Sweep =   18 | Direction =  forward | Bond dimension =  200 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =     66.243 | E =     -24.9178072682 | DE = -1.07e-14 | DW = 5.61555e-20
#
# Sweep =   19 | Direction = backward | Bond dimension =  200 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =     70.453 | E =     -24.9178072682 | DE = -1.14e-13 | DW = 7.10129e-20
#
# Sweep =   20 | Direction =  forward | Bond dimension =  500 | Noise =  0.00e+00 | Dav threshold =  1.00e-11
# Time elapsed =     82.738 | E =     -24.9178072682 | DE = -4.26e-11 | DW = 1.56649e-19
#
# Sweep =   21 | Direction = backward | Bond dimension =  500 | Noise =  0.00e+00 | Dav threshold =  1.00e-11
# Time elapsed =     94.073 | E =     -24.9178072682 | DE = -2.66e-13 | DW = 1.21695e-19
#
# Sweep =   22 | Direction =  forward | Bond dimension =  500 | Noise =  0.00e+00 | Dav threshold =  1.00e-11
# Time elapsed =    104.120 | E =     -24.9178072682 | DE = -3.91e-14 | DW = 8.49344e-20
#
# Sweep =   23 | Direction = backward | Bond dimension =  500 | Noise =  0.00e+00 | Dav threshold =  1.00e-11
# Time elapsed =    115.918 | E =     -24.9178072682 | DE = -4.26e-14 | DW = 1.02055e-19
#
# Sweep =   24 | Direction =  forward | Bond dimension =  500 | Noise =  0.00e+00 | Dav threshold =  1.00e-11
# Time elapsed =    129.949 | E =     -24.9178072682 | DE = -1.42e-14 | DW = 8.44937e-20
#
# Sweep =   25 | Direction = backward | Bond dimension = 1000 | Noise =  0.00e+00 | Dav threshold =  1.00e-11
# Time elapsed =    139.019 | E =     -24.9178072682 | DE = 4.97e-14 | DW = 1.04986e-19
#
# Final bond dimension = 140

# %% [markdown]
# ## <font color='blue'>Evolution over sweeps</font>

# %%
bonddims, discardedweights, energies = driver.get_dmrg_results()
plt.plot(energies.flatten(), marker='o')
plt.xlabel('Sweep', fontsize=12)
plt.ylabel('Energy', fontsize=12)
plt.show()
plt.plot(bonddims, marker='o')
plt.xlabel('Sweep', fontsize=12)
plt.ylabel('Bond dimension', fontsize=12)
plt.show()
plt.plot(discardedweights, marker='o')
plt.xlabel('Sweep', fontsize=12)
plt.ylabel('Discarded weight', fontsize=12)
plt.yscale('log')
plt.show()

# %% [markdown]
# ## <font color='blue'>Entanglement</font>

# %%
SvN = driver.get_bipartite_entanglement()

plt.plot(np.arange(1,L), SvN, marker='o')
plt.xlabel('Bond', fontsize=12)
plt.ylabel('Entanglement entropy', fontsize=12)
plt.show()

# %% [markdown]
# ## <font color='blue'>Single-particle boson correlations</font>

# %% [markdown]
# ### Calculate

# %%
start_time = time.time()

bosoncorr_mat = driver.get_npdm(mps, npdm_expr='cd', fermionic_ops='', mask=[0, 1])[0]
navg = np.diag(bosoncorr_mat)
print("Total number =", sum(navg))

end_time = time.time()
elapsed_time = end_time - start_time
print(f"Elapsed time: {elapsed_time} seconds")
# Out:
# Total number = 64.0000000000005
# Elapsed time: 15.051774024963379 seconds

# %% [markdown]
# ### Site occupations

# %%
plt.plot(np.arange(L), navg, marker='o')
plt.xlabel('Site', fontsize=12)
plt.ylabel('Occupation', fontsize=12)
plt.show()

# %% [markdown]
# ### Correlation matrix

# %%
plt.matshow(bosoncorr_mat, cmap='viridis', vmin=bosoncorr_mat.min(), vmax=bosoncorr_mat.max())
plt.colorbar()
plt.xlabel('Site j', fontsize=12)
plt.ylabel('Site i', fontsize=12)
plt.title(r'Boson correlation $\langle \hat{b}_{i}^{\dagger} \hat{b}_{j} \rangle$')
plt.show()

# %% [markdown]
# ### Correlation vs distance

# %%
plt.plot(np.arange(1,L//2+1), bosoncorr_mat[L//2-1,L//2:], marker='o')
plt.xlabel('Separation $r$', fontsize=12)
plt.ylabel(r'Correlation $\langle \hat{b}_{L/2}^{\dagger} \hat{b}_{L/2+r} \rangle$', fontsize=12)
plt.yscale('log')
plt.xscale('linear')
plt.show()

# %% [markdown]
# ### Momentum distribution

# %%
klist = (2*np.pi/L)*np.arange(-L//2,L//2)
fourier = np.array([[np.exp(1j*k*j) for j in np.arange(L)] for k in klist])
fourier_inverse = fourier.conj().T
boson_momentum_corr = np.dot(np.dot(fourier, bosoncorr_mat), fourier_inverse)/L
boson_momentum_dist = np.real(np.diag(boson_momentum_corr))
print("Total number =", sum(boson_momentum_dist))

plt.plot(klist, boson_momentum_dist, marker='o')
plt.xlabel('Quasimomentum $k$', fontsize=12)
plt.ylabel(r'Boson occupation  $\langle \hat{b}_k^{\dagger} \hat{b}_k \rangle$', fontsize=12)
plt.yscale('linear')
plt.xscale('linear')
plt.ylim(0, 1.05*max(boson_momentum_dist))
plt.show()
# Out:
# Total number = 64.0000000000005

# %% [markdown]
# ### Single-particle modes

# %%
bosoncorr_eigvals = np.sort(np.linalg.eigvals(bosoncorr_mat))[::-1]
plt.plot(np.arange(1,L+1), bosoncorr_eigvals, marker='o')
plt.xlabel('Boson mode', fontsize=12)
plt.ylabel('Occupation', fontsize=12)
plt.yscale('linear')
plt.xscale('linear')
plt.ylim(0, 1.05*max(bosoncorr_eigvals))
plt.show()

# %% [markdown]
# ## <font color='blue'>On-site number distribution</font>

# %% [markdown]
# ### Calculate

# %%
start_time = time.time()

ndist = np.array(driver.get_npdm(mps, npdm_expr=proj_keys, fermionic_ops='')).T
print("Deviation from unit filling =", np.linalg.norm([ndist[i].sum()-1 for i in range(L)]))

end_time = time.time()
elapsed_time = end_time - start_time
print(f"Elapsed time: {elapsed_time} seconds")
# Out:
# Deviation from unit filling = 6.606750562877023e-14
# Elapsed time: 9.68388032913208 seconds

# %% [markdown]
# ### Site-averaged number distribution

# %%
plt.plot(np.mean(ndist, axis=0), marker='o')
plt.xlabel('$n$', fontsize=12)
plt.ylabel('Site-avgd distribution $p(n)$', fontsize=12)
plt.yscale('linear')
plt.show()

# %% [markdown]
# ### Number fluctuation

# %%
nsqavg = np.array([np.dot(np.arange(nmax+1)**2, ndist[i]) for i in range(L)])
numfluc = np.sqrt(nsqavg - navg*navg)
plt.plot(np.arange(L), numfluc, marker='o')
plt.xlabel('Site', fontsize=12)
plt.ylabel('Number fluctuation', fontsize=12)
plt.title(f"Avg = {np.mean(numfluc)}")
plt.show()

# %% [markdown]
# ## <font color='blue'>Density-density correlations</font>

# %% [markdown]
# ### Calculate

# %%
start_time = time.time()

nnexp_mat = driver.get_npdm(mps, npdm_expr='cdcd', fermionic_ops='', mask=[0, 0, 1, 1])[0]
densitycorr_mat = nnexp_mat - np.outer(navg, navg)
print("Avg number fluctuation =", np.mean(np.sqrt(np.diag(densitycorr_mat))))

end_time = time.time()
elapsed_time = end_time - start_time
print(f"Elapsed time: {elapsed_time} seconds")
# Out:
# Avg number fluctuation = 0.27530602465381954
# Elapsed time: 9.64894962310791 seconds

# %% [markdown]
# ### Correlation matrix

# %%
plt.matshow(densitycorr_mat, cmap='seismic', vmin=-np.abs(densitycorr_mat).max(), vmax=np.abs(densitycorr_mat).max())
plt.colorbar()
plt.xlabel('Site j', fontsize=12)
plt.ylabel('Site i', fontsize=12)
plt.title(r'Density correlation $\langle \hat{n}_{i}, \hat{n}_{j} \rangle$')
plt.show()

# %% [markdown]
# ### Correlation vs distance

# %%
plt.plot(np.arange(1,L//2+1), -densitycorr_mat[L//2-1,L//2:], marker='o')
plt.xlabel('Separation $r$', fontsize=12)
plt.ylabel(r'Correlation $-\langle \hat{n}_{L/2}, \hat{n}_{L/2+r} \rangle$', fontsize=12)
plt.yscale('log')
plt.xscale('linear')
plt.show()

# %% [markdown]
# # <font color='red'>Boson with $U/t = 2$</font>

# %% [markdown]
# ## <font color='blue'>Parameters</font>

# %%
L = 64
N = 64
t = 1.0
U = 2.0
nmax = 5

driver = DMRGDriver(scratch="./tmp", symm_type=SymmetryTypes.SAny, n_threads=4)

driver.set_symmetry_groups("U1")
Q = driver.bw.SX

# %% [markdown]
# ## <font color='blue'>Local operators</font>

# %%
# [Part A] Set states and matrix representation of operators in local Hilbert space
site_basis, site_ops = [], []

basis = [(Q(i), 1) for i in range(nmax + 1)]

bdag = np.diag([np.sqrt(n+1) for n in range(nmax)], -1)
b = bdag.T
ops = {
    "": np.identity(nmax + 1), 
    "c": bdag, 
    "d": b
}

#proj_keys = ["P"+str(n) for n in range(nmax+1)]
proj_keys = ["Q","R","S","T","U","V","W","X","Y"][:nmax+1]
proj_ops = []
for n in range(nmax+1):
    proj_diag = np.diag(np.repeat([0, 1., 0], [n, 1, nmax-n]))
    proj_ops.append(proj_diag)
proj_dict = {}
for n in range(nmax+1):
    proj_dict[proj_keys[n]] = proj_ops[n]

for k in range(L): 
    site_basis.append(basis)
    site_ops.append(ops | proj_dict)

# %% [markdown]
# ## <font color='blue'>Hamiltonian</font>

# %%
# [Part B] Set Hamiltonian terms
driver.initialize_system(n_sites=L, vacuum=Q(0), target=Q(N), hamil_init=False)
driver.ghamil = driver.get_custom_hamiltonian(site_basis, site_ops)
os = driver.expr_builder()

for i in range(L-1):
    os.add_term("cd", [i, i+1], -t)
    os.add_term("cd", [i+1, i], -t)
for i in range(L):
    os.add_term("ccdd", [i, i, i, i], U/2)

# [Part C] Perform DMRG
mpo = driver.get_mpo(os.finalize(adjust_order=True, fermionic_ops=""), algo_type=MPOAlgorithmTypes.FastBipartite)

# %% [markdown]
# ## <font color='blue'>DMRG</font>

# %%
mps = driver.get_random_mps(tag="KET", bond_dim=50, nroots=1, occs=[1] * L)
energy = driver.dmrg(
    mpo, 
    mps, 
    n_sweeps=100, 
    bond_dims=[50] * 10 + [100] * 5 + [200] * 5 + [500] * 5 + [1000] * 5, 
    noises=[1e-3] * 3 + [1e-5] * 3 + [0],  
    thrds=[1e-10] * 20, 
    dav_max_iter=100, 
    tol=1e-10, 
    iprint=1)
print("Final bond dimension =", mps.info.get_max_bond_dimension())
# Out:
# Sweep =    0 | Direction =  forward | Bond dimension =   50 | Noise =  1.00e-03 | Dav threshold =  1.00e-10
# Time elapsed =      0.489 | E =     -82.2889210900 | DW = 4.72012e-11
#
# Sweep =    1 | Direction = backward | Bond dimension =   50 | Noise =  1.00e-03 | Dav threshold =  1.00e-10
# Time elapsed =      1.848 | E =     -83.9674067168 | DE = -1.68e+00 | DW = 1.27891e-08
#
# Sweep =    2 | Direction =  forward | Bond dimension =   50 | Noise =  1.00e-03 | Dav threshold =  1.00e-10
# Time elapsed =      4.024 | E =     -84.4881352505 | DE = -5.21e-01 | DW = 3.92048e-08
#
# Sweep =    3 | Direction = backward | Bond dimension =   50 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =      5.290 | E =     -84.6649990672 | DE = -1.77e-01 | DW = 2.04924e-08
#
# Sweep =    4 | Direction =  forward | Bond dimension =   50 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =      7.102 | E =     -84.6917743874 | DE = -2.68e-02 | DW = 7.16446e-08
#
# Sweep =    5 | Direction = backward | Bond dimension =   50 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =      8.316 | E =     -84.6934732809 | DE = -1.70e-03 | DW = 2.02568e-07
#
# Sweep =    6 | Direction =  forward | Bond dimension =   50 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =      9.056 | E =     -84.6935206456 | DE = -4.74e-05 | DW = 2.33845e-07
#
# Sweep =    7 | Direction = backward | Bond dimension =   50 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =      9.377 | E =     -84.6935226053 | DE = -1.96e-06 | DW = 2.61893e-07
#
# Sweep =    8 | Direction =  forward | Bond dimension =   50 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =      9.667 | E =     -84.6935230522 | DE = -4.47e-07 | DW = 2.72903e-07
#
# Sweep =    9 | Direction = backward | Bond dimension =   50 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =      9.926 | E =     -84.6935229643 | DE = 8.78e-08 | DW = 2.73319e-07
#
# Sweep =   10 | Direction =  forward | Bond dimension =  100 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =     10.833 | E =     -84.6935955095 | DE = -7.25e-05 | DW = 8.75883e-10
#
# Sweep =   11 | Direction = backward | Bond dimension =  100 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =     11.523 | E =     -84.6935961033 | DE = -5.94e-07 | DW = 3.38797e-09
#
# Sweep =   12 | Direction =  forward | Bond dimension =  100 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =     11.944 | E =     -84.6935961351 | DE = -3.18e-08 | DW = 3.79057e-09
#
# Sweep =   13 | Direction = backward | Bond dimension =  100 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =     12.333 | E =     -84.6935961282 | DE = 6.87e-09 | DW = 3.86648e-09
#
# Sweep =   14 | Direction =  forward | Bond dimension =  100 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =     12.776 | E =     -84.6935961254 | DE = 2.84e-09 | DW = 3.87173e-09
#
# Sweep =   15 | Direction = backward | Bond dimension =  200 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =     13.839 | E =     -84.6935970339 | DE = -9.09e-07 | DW = 7.30456e-12
#
# Sweep =   16 | Direction =  forward | Bond dimension =  200 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =     14.875 | E =     -84.6935970368 | DE = -2.93e-09 | DW = 2.19224e-11
#
# Sweep =   17 | Direction = backward | Bond dimension =  200 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =     15.763 | E =     -84.6935970372 | DE = -3.41e-10 | DW = 2.00268e-11
#
# Sweep =   18 | Direction =  forward | Bond dimension =  200 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =     16.652 | E =     -84.6935970373 | DE = -1.01e-10 | DW = 2.01712e-11
#
# Sweep =   19 | Direction = backward | Bond dimension =  200 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =     17.573 | E =     -84.6935970373 | DE = -9.05e-12 | DW = 2.02531e-11
#
# Sweep =   20 | Direction =  forward | Bond dimension =  500 | Noise =  0.00e+00 | Dav threshold =  1.00e-11
# Time elapsed =     22.230 | E =     -84.6935970425 | DE = -5.25e-09 | DW = 2.22853e-15
#
# Sweep =   21 | Direction = backward | Bond dimension =  500 | Noise =  0.00e+00 | Dav threshold =  1.00e-11
# Time elapsed =     27.710 | E =     -84.6935970425 | DE = -2.27e-11 | DW = 6.29444e-15
#
# Sweep =   22 | Direction =  forward | Bond dimension =  500 | Noise =  0.00e+00 | Dav threshold =  1.00e-11
# Time elapsed =     33.090 | E =     -84.6935970425 | DE = -1.53e-12 | DW = 1.61979e-16
#
# Sweep =   23 | Direction = backward | Bond dimension =  500 | Noise =  0.00e+00 | Dav threshold =  1.00e-11
# Time elapsed =     38.417 | E =     -84.6935970425 | DE = 3.98e-13 | DW = 5.29654e-16
#
# Sweep =   24 | Direction =  forward | Bond dimension =  500 | Noise =  0.00e+00 | Dav threshold =  1.00e-11
# Time elapsed =     43.819 | E =     -84.6935970425 | DE = 7.11e-14 | DW = 1.17622e-16
#
# Sweep =   25 | Direction = backward | Bond dimension = 1000 | Noise =  0.00e+00 | Dav threshold =  1.00e-11
# Time elapsed =     50.331 | E =     -84.6935970425 | DE = 2.98e-13 | DW = 1.73714e-19
#
# Final bond dimension = 602

# %% [markdown]
# ## <font color='blue'>Evolution over sweeps</font>

# %%
bonddims, discardedweights, energies = driver.get_dmrg_results()
plt.plot(energies.flatten(), marker='o')
plt.xlabel('Sweep', fontsize=12)
plt.ylabel('Energy', fontsize=12)
plt.show()
plt.plot(bonddims, marker='o')
plt.xlabel('Sweep', fontsize=12)
plt.ylabel('Bond dimension', fontsize=12)
plt.show()
plt.plot(discardedweights, marker='o')
plt.xlabel('Sweep', fontsize=12)
plt.ylabel('Discarded weight', fontsize=12)
plt.yscale('log')
plt.show()

# %% [markdown]
# ## <font color='blue'>Entanglement</font>

# %%
SvN = driver.get_bipartite_entanglement()

plt.plot(np.arange(1,L), SvN, marker='o')
plt.xlabel('Bond', fontsize=12)
plt.ylabel('Entanglement entropy', fontsize=12)
plt.show()

# %% [markdown]
# ## <font color='blue'>Single-particle boson correlations</font>

# %% [markdown]
# ### Calculate

# %%
start_time = time.time()

bosoncorr_mat = driver.get_npdm(mps, npdm_expr='cd', fermionic_ops='', mask=[0, 1])[0]
navg = np.diag(bosoncorr_mat)
print("Total number =", sum(navg))

end_time = time.time()
elapsed_time = end_time - start_time
print(f"Elapsed time: {elapsed_time} seconds")
# Out:
# Total number = 63.99999999999937
# Elapsed time: 9.042630195617676 seconds

# %% [markdown]
# ### Site occupations

# %%
plt.plot(np.arange(L), navg, marker='o')
plt.xlabel('Site', fontsize=12)
plt.ylabel('Occupation', fontsize=12)
plt.show()

# %% [markdown]
# ### Correlation matrix

# %%
plt.matshow(bosoncorr_mat, cmap='viridis', vmin=bosoncorr_mat.min(), vmax=bosoncorr_mat.max())
plt.colorbar()
plt.xlabel('Site j', fontsize=12)
plt.ylabel('Site i', fontsize=12)
plt.title(r'Boson correlation $\langle \hat{b}_{i}^{\dagger} \hat{b}_{j} \rangle$')
plt.show()

# %% [markdown]
# ### Correlation vs distance

# %%
plt.plot(np.arange(1,L//2+1), bosoncorr_mat[L//2-1,L//2:], marker='o')
plt.xlabel('Separation $r$', fontsize=12)
plt.ylabel(r'Correlation $\langle \hat{b}_{L/2}^{\dagger} \hat{b}_{L/2+r} \rangle$', fontsize=12)
plt.yscale('log')
plt.xscale('log')
plt.show()

# %% [markdown]
# ### Momentum distribution

# %%
klist = (2*np.pi/L)*np.arange(-L//2,L//2)
fourier = np.array([[np.exp(1j*k*j) for j in np.arange(L)] for k in klist])
fourier_inverse = fourier.conj().T
boson_momentum_corr = np.dot(np.dot(fourier, bosoncorr_mat), fourier_inverse)/L
boson_momentum_dist = np.real(np.diag(boson_momentum_corr))
print("Total number =", sum(boson_momentum_dist))

plt.plot(klist, boson_momentum_dist, marker='o')
plt.xlabel('Quasimomentum $k$', fontsize=12)
plt.ylabel(r'Boson occupation  $\langle \hat{b}_k^{\dagger} \hat{b}_k \rangle$', fontsize=12)
plt.yscale('linear')
plt.xscale('linear')
#plt.ylim(0, 1.05*max(boson_momentum_dist))
plt.show()
# Out:
# Total number = 63.999999999999346

# %% [markdown]
# ### Single-particle modes

# %%
bosoncorr_eigvals = np.sort(np.linalg.eigvals(bosoncorr_mat))[::-1]
plt.plot(np.arange(1,L+1), bosoncorr_eigvals, marker='o')
plt.xlabel('Boson mode', fontsize=12)
plt.ylabel('Occupation', fontsize=12)
plt.yscale('log')
plt.xscale('log')
#plt.ylim(0, 1.05*max(bosoncorr_eigvals))
plt.show()

# %% [markdown]
# ## <font color='blue'>On-site number distribution</font>

# %% [markdown]
# ### Calculate

# %%
start_time = time.time()

ndist = np.array(driver.get_npdm(mps, npdm_expr=proj_keys, fermionic_ops='')).T
print("Deviation from unit filling =", np.linalg.norm([ndist[i].sum()-1 for i in range(L)]))

end_time = time.time()
elapsed_time = end_time - start_time
print(f"Elapsed time: {elapsed_time} seconds")
# Out:
# Deviation from unit filling = 8.269723334300402e-14
# Elapsed time: 4.957105875015259 seconds

# %% [markdown]
# ### Site-averaged number distribution

# %%
plt.plot(np.mean(ndist, axis=0), marker='o', label='Actual')
plt.xlabel('$n$', fontsize=12)
plt.ylabel('Site-avgd distribution $p(n)$', fontsize=12)
plt.yscale('linear')
#plt.plot([1/(np.e*math.factorial(n)) for n in range(nmax+1)], marker='o', label='Poisson')
#plt.legend()
plt.show()

# %% [markdown]
# ### Number fluctuation

# %%
nsqavg = np.array([np.dot(np.arange(nmax+1)**2, ndist[i]) for i in range(L)])
numfluc = np.sqrt(nsqavg - navg*navg)
plt.plot(np.arange(L), numfluc, marker='o')
plt.xlabel('Site', fontsize=12)
plt.ylabel('Number fluctuation', fontsize=12)
plt.title(f"Avg = {np.mean(numfluc)}")
plt.show()

# %% [markdown]
# ## <font color='blue'>Density-density correlations</font>

# %% [markdown]
# ### Calculate

# %%
start_time = time.time()

nnexp_mat = driver.get_npdm(mps, npdm_expr='cdcd', fermionic_ops='', mask=[0, 0, 1, 1])[0]
densitycorr_mat = nnexp_mat - np.outer(navg, navg)
print("Avg number fluctuation =", np.mean(np.sqrt(np.diag(densitycorr_mat))))

end_time = time.time()
elapsed_time = end_time - start_time
print(f"Elapsed time: {elapsed_time} seconds")
# Out:
# Avg number fluctuation = 0.7155239162028892
# Elapsed time: 6.863505840301514 seconds

# %% [markdown]
# ### Correlation matrix

# %%
plt.matshow(densitycorr_mat, cmap='seismic', vmin=-np.abs(densitycorr_mat).max(), vmax=np.abs(densitycorr_mat).max())
plt.colorbar()
plt.xlabel('Site j', fontsize=12)
plt.ylabel('Site i', fontsize=12)
plt.title(r'Density correlation $\langle \hat{n}_{i}, \hat{n}_{j} \rangle$')
plt.show()

# %% [markdown]
# ### Correlation vs distance

# %%
plt.plot(np.arange(1,L//2+1), -densitycorr_mat[L//2-1,L//2:], marker='o')
plt.xlabel('Separation $r$', fontsize=12)
plt.ylabel(r'Correlation $-\langle \hat{n}_{L/2}, \hat{n}_{L/2+r} \rangle$', fontsize=12)
plt.yscale('log')
plt.xscale('log')
plt.show()

# %% [markdown]
# # <font color='red'>Pseudofermion with $U/t=2$</font>

# %% [markdown]
# ## <font color='blue'>Parameters</font>

# %%
L = 64
N = 64
t = 1.0
U = 2.0
nmax = 5

driver = DMRGDriver(scratch="./tmp", symm_type=SymmetryTypes.SAny, n_threads=4)

driver.set_symmetry_groups("U1")
Q = driver.bw.SX

# %% [markdown]
# ## <font color='blue'>Local operators</font>

# %%
# [Part A] Set states and matrix representation of operators in local Hilbert space
site_basis, site_ops = [], []

basis = [(Q(i), 1) for i in range(nmax + 1)]

bdag = np.diag([np.sqrt(n+1) for n in range(nmax)], -1)
b = bdag.T
adag = np.diag([np.sqrt(n+1) * (-1)**n for n in range(nmax)], -1)
a = adag.T
parity = np.diag([(-1.)**n for n in range(nmax+1)])
ops = {
    "": np.identity(nmax + 1), 
    "c": bdag, 
    "d": b, 
    "C": adag, 
    "D": a, 
    "P": parity
}

#proj_keys = ["P"+str(n) for n in range(nmax+1)]
proj_keys = ["Q","R","S","T","U","V","W","X","Y"][:nmax+1]
proj_ops = []
for n in range(nmax+1):
    proj_diag = np.diag(np.repeat([0, 1., 0], [n, 1, nmax-n]))
    proj_ops.append(proj_diag)
proj_dict = {}
for n in range(nmax+1):
    proj_dict[proj_keys[n]] = proj_ops[n]

for k in range(L): 
    site_basis.append(basis)
    site_ops.append(ops | proj_dict)

# %% [markdown]
# ## <font color='blue'>Hamiltonian</font>

# %%
# [Part B] Set Hamiltonian terms
driver.initialize_system(n_sites=L, vacuum=Q(0), target=Q(N), hamil_init=False)
driver.ghamil = driver.get_custom_hamiltonian(site_basis, site_ops)
os = driver.expr_builder()

for i in range(L-1):
    os.add_term("Cd", [i, i+1], -t)
    os.add_term("cD", [i+1, i], -t)
for i in range(L):
    os.add_term("ccdd", [i, i, i, i], U/2)

# [Part C] Perform DMRG
mpo = driver.get_mpo(os.finalize(adjust_order=True, fermionic_ops=""), algo_type=MPOAlgorithmTypes.FastBipartite)

# %% [markdown]
# ## <font color='blue'>DMRG</font>

# %%
mps = driver.get_random_mps(tag="KET", bond_dim=50, nroots=1, occs=[1] * L)
energy = driver.dmrg(
    mpo, 
    mps, 
    n_sweeps=100, 
    bond_dims=[50] * 10 + [100] * 5 + [200] * 5 + [500] * 5 + [1000] * 5, 
    noises=[1e-3] * 3 + [1e-5] * 3 + [0],  
    thrds=[1e-10] * 20, 
    dav_max_iter=100, 
    tol=1e-10, 
    iprint=1)
print("Final bond dimension =", mps.info.get_max_bond_dimension())
# Out:
# Sweep =    0 | Direction =  forward | Bond dimension =   50 | Noise =  1.00e-03 | Dav threshold =  1.00e-10
# Time elapsed =      1.175 | E =     -51.2624099768 | DW = 3.24528e-08
#
# Sweep =    1 | Direction = backward | Bond dimension =   50 | Noise =  1.00e-03 | Dav threshold =  1.00e-10
# Time elapsed =      5.713 | E =     -52.8105554194 | DE = -1.55e+00 | DW = 3.48698e-07
#
# Sweep =    2 | Direction =  forward | Bond dimension =   50 | Noise =  1.00e-03 | Dav threshold =  1.00e-10
# Time elapsed =     10.203 | E =     -53.7621488450 | DE = -9.52e-01 | DW = 7.37616e-07
#
# Sweep =    3 | Direction = backward | Bond dimension =   50 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =     13.856 | E =     -54.5753726901 | DE = -8.13e-01 | DW = 3.00975e-07
#
# Sweep =    4 | Direction =  forward | Bond dimension =   50 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =     18.391 | E =     -54.6805608898 | DE = -1.05e-01 | DW = 5.88922e-07
#
# Sweep =    5 | Direction = backward | Bond dimension =   50 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =     22.051 | E =     -55.4976475077 | DE = -8.17e-01 | DW = 4.66196e-07
#
# Sweep =    6 | Direction =  forward | Bond dimension =   50 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =     25.665 | E =     -56.2993538989 | DE = -8.02e-01 | DW = 6.58886e-07
#
# Sweep =    7 | Direction = backward | Bond dimension =   50 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =     28.385 | E =     -56.3114443916 | DE = -1.21e-02 | DW = 3.75654e-07
#
# Sweep =    8 | Direction =  forward | Bond dimension =   50 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =     31.018 | E =     -57.1032003666 | DE = -7.92e-01 | DW = 3.92960e-07
#
# Sweep =    9 | Direction = backward | Bond dimension =   50 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =     32.499 | E =     -57.1056359072 | DE = -2.44e-03 | DW = 3.17718e-08
#
# Sweep =   10 | Direction =  forward | Bond dimension =  100 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =     36.512 | E =     -57.7873379845 | DE = -6.82e-01 | DW = 1.24145e-10
#
# Sweep =   11 | Direction = backward | Bond dimension =  100 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =     38.138 | E =     -57.8174369500 | DE = -3.01e-02 | DW = 7.25910e-13
#
# Sweep =   12 | Direction =  forward | Bond dimension =  100 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =     38.587 | E =     -57.8174369557 | DE = -5.77e-09 | DW = 6.81161e-13
#
# Sweep =   13 | Direction = backward | Bond dimension =  100 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =     38.965 | E =     -57.8174369558 | DE = -4.71e-11 | DW = 4.40412e-13
#
# Sweep =   14 | Direction =  forward | Bond dimension =  100 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =     39.396 | E =     -57.8174369558 | DE = -6.33e-12 | DW = 4.35021e-13
#
# Sweep =   15 | Direction = backward | Bond dimension =  200 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =     40.218 | E =     -57.8174369562 | DE = -4.13e-10 | DW = 4.79116e-16
#
# Sweep =   16 | Direction =  forward | Bond dimension =  200 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =     41.151 | E =     -57.8174369562 | DE = -6.82e-13 | DW = 1.04474e-16
#
# Sweep =   17 | Direction = backward | Bond dimension =  200 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =     42.180 | E =     -57.8174369562 | DE = 2.27e-13 | DW = 5.00927e-17
#
# Sweep =   18 | Direction =  forward | Bond dimension =  200 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =     43.113 | E =     -57.8174369562 | DE = -1.21e-13 | DW = 9.62231e-17
#
# Sweep =   19 | Direction = backward | Bond dimension =  200 | Noise =  0.00e+00 | Dav threshold =  1.00e-10
# Time elapsed =     44.034 | E =     -57.8174369562 | DE = 1.56e-13 | DW = 4.23849e-17
#
# Sweep =   20 | Direction =  forward | Bond dimension =  500 | Noise =  0.00e+00 | Dav threshold =  1.00e-11
# Time elapsed =     47.532 | E =     -57.8174369563 | DE = -5.37e-11 | DW = 3.61100e-19
#
# Sweep =   21 | Direction = backward | Bond dimension =  500 | Noise =  0.00e+00 | Dav threshold =  1.00e-11
# Time elapsed =     52.243 | E =     -57.8174369563 | DE = -1.93e-12 | DW = 2.51860e-19
#
# Sweep =   22 | Direction =  forward | Bond dimension =  500 | Noise =  0.00e+00 | Dav threshold =  1.00e-11
# Time elapsed =     56.615 | E =     -57.8174369563 | DE = -1.35e-13 | DW = 1.18807e-19
#
# Sweep =   23 | Direction = backward | Bond dimension =  500 | Noise =  0.00e+00 | Dav threshold =  1.00e-11
# Time elapsed =     61.091 | E =     -57.8174369563 | DE = 7.11e-15 | DW = 1.45384e-19
#
# Sweep =   24 | Direction =  forward | Bond dimension =  500 | Noise =  0.00e+00 | Dav threshold =  1.00e-11
# Time elapsed =     65.421 | E =     -57.8174369563 | DE = 1.56e-13 | DW = 9.75157e-20
#
# Sweep =   25 | Direction = backward | Bond dimension = 1000 | Noise =  0.00e+00 | Dav threshold =  1.00e-11
# Time elapsed =     69.815 | E =     -57.8174369563 | DE = -3.34e-13 | DW = 1.34126e-19
#
# Final bond dimension = 415

# %% [markdown]
# ## <font color='blue'>Evolution over sweeps</font>

# %%
bonddims, discardedweights, energies = driver.get_dmrg_results()
plt.plot(energies.flatten(), marker='o')
plt.xlabel('Sweep', fontsize=12)
plt.ylabel('Energy', fontsize=12)
plt.show()
plt.plot(bonddims, marker='o')
plt.xlabel('Sweep', fontsize=12)
plt.ylabel('Bond dimension', fontsize=12)
plt.show()
plt.plot(discardedweights, marker='o')
plt.xlabel('Sweep', fontsize=12)
plt.ylabel('Discarded weight', fontsize=12)
plt.yscale('log')
plt.show()

# %% [markdown]
# ## <font color='blue'>Entanglement</font>

# %%
SvN = driver.get_bipartite_entanglement()

plt.plot(np.arange(1,L), SvN, marker='o')
plt.xlabel('Bond', fontsize=12)
plt.ylabel('Entanglement entropy', fontsize=12)
plt.show()

# %% [markdown]
# ## <font color='blue'>Single-particle boson correlations</font>

# %% [markdown]
# ### Calculate

# %%
start_time = time.time()

bosoncorr_mat = driver.get_npdm(mps, npdm_expr='cd', fermionic_ops='', mask=[0, 1])[0]
navg = np.diag(bosoncorr_mat)
print("Total number =", sum(navg))

end_time = time.time()
elapsed_time = end_time - start_time
print(f"Elapsed time: {elapsed_time} seconds")
# Out:
# Total number = 63.99999999999953
# Elapsed time: 5.925768852233887 seconds

# %% [markdown]
# ### Site occupations

# %%
plt.plot(np.arange(L), navg, marker='o')
plt.xlabel('Site', fontsize=12)
plt.ylabel('Occupation', fontsize=12)
plt.show()

# %% [markdown]
# ### Correlation matrix

# %%
plt.matshow(bosoncorr_mat, cmap='seismic', vmin=-np.abs(bosoncorr_mat).max(), vmax=np.abs(bosoncorr_mat).max())
plt.colorbar()
plt.xlabel('Site j', fontsize=12)
plt.ylabel('Site i', fontsize=12)
plt.title(r'Boson correlation $\langle \hat{b}_{i}^{\dagger} \hat{b}_{j} \rangle$')
plt.show()

# %% [markdown]
# ### Correlation vs distance

# %%
plt.plot(np.arange(1,L//2+1), bosoncorr_mat[L//2-1,L//2:], marker='o')
plt.xlabel('Separation $r$', fontsize=12)
plt.ylabel(r'Correlation $\langle \hat{b}_{L/2}^{\dagger} \hat{b}_{L/2+r} \rangle$', fontsize=12)
plt.show()

# %%
plt.plot(np.arange(1,L//2+1), abs(bosoncorr_mat[L//2-1,L//2:]), marker='o')
plt.xlabel('Separation $r$', fontsize=12)
plt.ylabel(r'Correlation $|\langle \hat{b}_{L/2}^{\dagger} \hat{b}_{L/2+r} \rangle|$', fontsize=12)
plt.yscale('log')
plt.show()

# %% [markdown]
# ### Momentum distribution

# %%
klist = (2*np.pi/L)*np.arange(-L//2,L//2)
fourier = np.array([[np.exp(1j*k*j) for j in np.arange(L)] for k in klist])
fourier_inverse = fourier.conj().T
boson_momentum_corr = np.dot(np.dot(fourier, bosoncorr_mat), fourier_inverse)/L
boson_momentum_dist = np.real(np.diag(boson_momentum_corr))
print("Total number =", sum(boson_momentum_dist))

plt.plot(klist, boson_momentum_dist, marker='o')
plt.xlabel('Quasimomentum $k$', fontsize=12)
plt.ylabel(r'Boson occupation  $\langle \hat{b}_k^{\dagger} \hat{b}_k \rangle$', fontsize=12)
plt.ylim(0, 1.05*max(boson_momentum_dist))
plt.show()
# Out:
# Total number = 63.99999999999954

# %% [markdown]
# ### Single-particle modes

# %%
bosoncorr_eigvals = np.sort(np.linalg.eigvals(bosoncorr_mat))[::-1]
plt.plot(bosoncorr_eigvals, marker='o')
plt.xlabel('Boson mode', fontsize=12)
plt.ylabel('Occupation', fontsize=12)
plt.ylim(0, 1.05*max(bosoncorr_eigvals))
plt.yscale('linear')
plt.show()

# %% [markdown]
# ## <font color='blue'>Single-particle anyon correlations</font>

# %% [markdown]
# ### Calculate

# %%
start_time = time.time()

anyoncorr = []
for i in range(L):
    for j in range(i,L):
        os = driver.expr_builder().add_term("c"+"".join(["P"]*(j-i))+"d", [i] + list(range(i,j+1)), 1)
        op = driver.get_mpo(os.finalize(adjust_order=True, fermionic_ops=""))
        opexp = driver.expectation(mps, op, mps)
        anyoncorr.append(opexp)
anyoncorr_mat = vector_to_hermitian(anyoncorr)
print("Site occupation mismatch =", np.linalg.norm(navg - np.diag(anyoncorr_mat)))

end_time = time.time()
elapsed_time = end_time - start_time
print(f"Elapsed time: {elapsed_time} seconds")
# Out:
# Site occupation mismatch = 3.790432133064851e-14
# Elapsed time: 376.3750469684601 seconds

# %% [markdown]
# ### Correlation matrix

# %%
plt.matshow(anyoncorr_mat, cmap='seismic', vmin=-np.abs(anyoncorr_mat).max(), vmax=np.abs(anyoncorr_mat).max())
plt.colorbar()
plt.xlabel('Site j', fontsize=12)
plt.ylabel('Site i', fontsize=12)
plt.title(r'Anyon correlation $\langle \hat{a}_{i}^{\dagger} \hat{a}_{j} \rangle$')
plt.show()

# %% [markdown]
# ### Correlation vs distance

# %%
plt.plot(np.arange(1,L//2+1), anyoncorr_mat[L//2-1,L//2:], marker='o')
plt.xlabel('Separation $r$', fontsize=12)
plt.ylabel(r'Correlation $\langle \hat{a}_{L/2}^{\dagger} \hat{a}_{L/2+r} \rangle$', fontsize=12)
plt.show()

# %%
plt.plot(np.arange(1,L//2+1), abs(anyoncorr_mat[L//2-1,L//2:]), marker='o')
plt.xlabel('Separation $r$', fontsize=12)
plt.ylabel(r'Correlation $\langle \hat{a}_{L/2}^{\dagger} \hat{a}_{L/2+r} \rangle$', fontsize=12)
plt.yscale('log')
plt.show()

# %% [markdown]
# ### Momentum distribution

# %%
klist = (2*np.pi/L)*np.arange(-L//2,L//2)
fourier = np.array([[np.exp(1j*k*j) for j in np.arange(L)] for k in klist])
fourier_inverse = fourier.conj().T
anyon_momentum_corr = np.dot(np.dot(fourier, anyoncorr_mat), fourier_inverse)/L
anyon_momentum_dist = np.real(np.diag(anyon_momentum_corr))
print("Total number =", sum(anyon_momentum_dist))

plt.plot(klist, anyon_momentum_dist, marker='o')
plt.xlabel('Quasimomentum $k$', fontsize=12)
plt.ylabel(r'Anyon occupation $\langle \hat{a}_k^{\dagger} \hat{a}_k \rangle$', fontsize=12)
plt.ylim(0, 1.05*max(anyon_momentum_dist))
plt.show()
# Out:
# Total number = 63.9999999999998

# %% [markdown]
# ### Single-particle modes

# %%
anyoncorr_eigvals = np.sort(np.linalg.eigvals(anyoncorr_mat))[::-1]
plt.plot(anyoncorr_eigvals, marker='o')
plt.xlabel('Anyon mode', fontsize=12)
plt.ylabel('Occupation', fontsize=12)
plt.ylim(0, 1.05*max(anyoncorr_eigvals))
plt.yscale('linear')
plt.show()

# %% [markdown]
# ## <font color='blue'>On-site number distribution</font>

# %% [markdown]
# ### Calculate

# %%
start_time = time.time()

ndist = np.array(driver.get_npdm(mps, npdm_expr=proj_keys, fermionic_ops='')).T
print("Deviation from unit filling =", np.linalg.norm([ndist[i].sum()-1 for i in range(L)]))

end_time = time.time()
elapsed_time = end_time - start_time
print(f"Elapsed time: {elapsed_time} seconds")
# Out:
# Deviation from unit filling = 5.916936708447561e-14
# Elapsed time: 3.0866880416870117 seconds

# %% [markdown]
# ### Site-averaged number distribution

# %%
plt.plot(np.mean(ndist, axis=0), marker='o')
plt.xlabel('$n$', fontsize=12)
plt.ylabel('Site-avgd distribution $p(n)$', fontsize=12)
plt.yscale('linear')
plt.show()

# %% [markdown]
# ### Number fluctuations

# %%
nsqavg = np.array([np.dot(np.arange(nmax+1)**2, ndist[i]) for i in range(L)])
numfluc = np.sqrt(nsqavg - navg*navg)
plt.plot(np.arange(L), numfluc, marker='o')
plt.xlabel('Site', fontsize=12)
plt.ylabel('Number fluctuation', fontsize=12)
plt.title(f"Avg = {np.mean(numfluc)}")
plt.show()

# %% [markdown]
# ## <font color='blue'>Density-density correlations</font>

# %% [markdown]
# ### Calculate

# %%
start_time = time.time()

nnexp_mat = driver.get_npdm(mps, npdm_expr='cdcd', fermionic_ops='', mask=[0, 0, 1, 1])[0]
densitycorr_mat = nnexp_mat - np.outer(navg, navg)
print("Avg number fluctuation =", np.mean(np.sqrt(np.diag(densitycorr_mat))))

end_time = time.time()
elapsed_time = end_time - start_time
print(f"Elapsed time: {elapsed_time} seconds")
# Out:
# Avg number fluctuation = 0.5309073109666749
# Elapsed time: 4.577620983123779 seconds

# %% [markdown]
# ### Correlation matrix

# %%
plt.matshow(densitycorr_mat, cmap='seismic', vmin=-np.abs(densitycorr_mat).max(), vmax=np.abs(densitycorr_mat).max())
plt.colorbar()
plt.xlabel('Site j', fontsize=12)
plt.ylabel('Site i', fontsize=12)
plt.title(r'Density correlation $\langle \hat{n}_{i}, \hat{n}_{j} \rangle$')
plt.show()

# %% [markdown]
# ### Correlation vs distance

# %%
plt.plot(np.arange(1,L//2+1), densitycorr_mat[L//2-1,L//2:], marker='o')
plt.xlabel('Separation $r$', fontsize=12)
plt.ylabel(r'Correlation $\langle \hat{n}_{L/2}, \hat{n}_{L/2+r} \rangle$', fontsize=12)
plt.show()

# %%
plt.plot(np.arange(1,L//2+1), abs(densitycorr_mat[L//2-1,L//2:]), marker='o')
plt.xlabel('Separation $r$', fontsize=12)
plt.ylabel(r'Correlation $|\langle \hat{n}_{L/2}, \hat{n}_{L/2+r} \rangle|$', fontsize=12)
plt.yscale('log')
plt.xscale('linear')
plt.show()
