# %%
from pyblock2.driver.core import DMRGDriver, SymmetryTypes, MPOAlgorithmTypes
import numpy as np
import matplotlib.pyplot as plt

# %%
# Initial Script
params={
    'L': 20,
    'u':1,
    't':1,
    'mu':0,
    'n_max':3,
    'n_boson':20,
}
params['t_list'] = np.arange(0, 1, 0.1)

def initialVals(params, **kwargs):
    '''
    Constructs states and matrix representation of operators in local hilbert space.
    Adds on-site potential and chemical potential terms to 'b'.
    Returns Q - Quantum Number Wrapper, b - ExprBuilder object, driver - DMRGDriver Object
    '''    
    driver = DMRGDriver(scratch="./tmp", symm_type=SymmetryTypes.SAny, n_threads=4)
    
    driver.set_symmetry_groups("U1")
    Q = driver.bw.SX
    site_basis, site_ops = [], []

    for k in range(params['L']):
        basis = [(Q(i), 1) for i in range(params['n_max'] + 1)] 
        ops = {
            "": np.identity(params['n_max'] + 1),                           # identity
            "C": np.diag(np.sqrt(np.arange(1, params['n_max'] + 1)), k=-1), # creation Op
            "D": np.diag(np.sqrt(np.arange(1, params['n_max'] + 1)), k=1),  # annihilation Op
            "N": np.diag(np.arange(0, params['n_max'] + 1), k=0),           # Number Operator
        }
        site_basis.append(basis)
        site_ops.append(ops)
    driver.initialize_system(n_sites=params['L'], vacuum=Q(0), target=Q(params['n_boson']), hamil_init=False)
    driver.ghamil = driver.get_custom_hamiltonian(site_basis, site_ops)
    b = driver.expr_builder()
    b.add_term("N", np.array(np.arange(params['L'])), -(params['mu'] + params['u'] / 2))
    b.add_term("NN", np.repeat(np.arange(params['L']), 2), params['u'] / 2)

    return Q, driver, b
Q, driver, b = initialVals(params)

# %%
def plot_FirstExcitationGapVsJ(params, **kwargs):
    '''
    Returns plot of First Excitation Gap as a function of J.
    '''
    Q, driver, b = initialVals(params)
    gaps = []
    for T in params['t_list']:
        try:
            b.add_term("CD", np.array([[i, i+1, i+1, i] for i in range(params['L']-1)]).flatten(), -T)
            mpo = driver.get_mpo(b.finalize(adjust_order=True, fermionic_ops=""), algo_type=MPOAlgorithmTypes.FastBipartite)
            mps = driver.get_random_mps(tag="KET", bond_dim=50, nroots=2)
            energy = driver.dmrg(mpo, mps, n_sweeps=10, bond_dims=[50] * 4 + [75] * 4,
                noises=[1e-4] * 4 + [1e-5] * 4 + [0], thrds=[1e-10] * 8, dav_max_iter=30, iprint=0)
            gaps.append(energy[1] - energy[0])
            print(f"t = {T:.2f}, Ground state energy = {energy[0]:.3f}, First excited state energy = {energy[1]:.3f}, Gap = {energy[1] - energy[0]:.3f}")
        
        except Exception as e:
            print(f"An error occurred for T={T:.2f}: {str(e)}")
            gaps.append(None)

    plt.plot(params['t_list'], gaps, marker='o')
    plt.xlabel('J')
    plt.ylabel('First Excitation Energy Gap')
    plt.title('First Excitation Energy Gap vs. Hopping Parameter J')
    plt.grid(True)
    plt.show()
    return gaps
gaps = plot_FirstExcitationGapVsJ(params)
# Out:
# Sweep =    0 | Direction =  forward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      0.118 | E[  2] =       0.0000000000      1.0000000000 | DW = 1.25330e-20
#
# Sweep =    1 | Direction = backward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      0.189 | E[  2] =       0.0000000000      1.0000000000 | DE = -1.11e-16 | DW = 4.10602e-22
#
# Sweep =    2 | Direction =  forward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      0.262 | E[  2] =       0.0000000000      1.0000000000 | DE = 1.11e-16 | DW = 9.50547e-22
#
# Sweep =    3 | Direction = backward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      0.324 | E[  2] =       0.0000000000      1.0000000000 | DE = 2.22e-16 | DW = 5.34319e-21
#
# Sweep =    4 | Direction =  forward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =      0.409 | E[  2] =       0.0000000000      1.0000000000 | DE = -2.22e-16 | DW = 2.01140e-21
#
# Sweep =    5 | Direction = backward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =      0.497 | E[  2] =       0.0000000000      1.0000000000 | DE = -3.33e-16 | DW = 3.47086e-21
#
# Sweep =    6 | Direction =  forward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =      0.578 | E[  2] =       0.0000000000      1.0000000000 | DE = 0.00e+00 | DW = 8.72025e-21
#
# Sweep =    7 | Direction = backward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =      0.652 | E[  2] =       0.0000000000      1.0000000000 | DE = 3.33e-16 | DW = 5.34459e-23
#
# Sweep =    8 | Direction =  forward | Bond dimension =   75 | Noise =  0.00e+00 | Dav threshold =  1.00e-09
# Time elapsed =      0.730 | E[  2] =       0.0000000000      1.0000000000 | DE = 0.00e+00 | DW = 2.39381e-21
#
# t = 0.00, Ground state energy = 0.000, First excited state energy = 1.000, Gap = 1.000
#
# Sweep =    0 | Direction =  forward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      0.281 | E[  2] =      -0.7506373446     -0.2585923706 | DW = 7.85354e-08
#
# Sweep =    1 | Direction = backward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      0.979 | E[  2] =      -0.7506734481     -0.2634276607 | DE = -4.84e-03 | DW = 1.57247e-09
#
# Sweep =    2 | Direction =  forward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      1.645 | E[  2] =      -0.7506734456     -0.2637492178 | DE = -3.22e-04 | DW = 3.21753e-09
#
# Sweep =    3 | Direction = backward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      2.147 | E[  2] =      -0.7506734439     -0.2637534236 | DE = -4.21e-06 | DW = 2.62915e-09
#
# Sweep =    4 | Direction =  forward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =      2.680 | E[  2] =      -0.7506734526     -0.2637535096 | DE = -8.61e-08 | DW = 2.41539e-11
#
# Sweep =    5 | Direction = backward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =      5.779 | E[  2] =      -0.7506734527     -0.2637535100 | DE = -4.14e-10 | DW = 2.55329e-11
#
# Sweep =    6 | Direction =  forward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =      8.456 | E[  2] =      -0.7506734527     -0.2637535102 | DE = -1.71e-10 | DW = 2.52678e-11
#
# Sweep =    7 | Direction = backward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =      9.868 | E[  2] =      -0.7506734527     -0.2637535102 | DE = -2.29e-11 | DW = 2.49549e-11
#
# Sweep =    8 | Direction =  forward | Bond dimension =   75 | Noise =  0.00e+00 | Dav threshold =  1.00e-09
# Time elapsed =     11.326 | E[  2] =      -0.7506734526     -0.2637535100 | DE = 2.71e-10 | DW = 7.71895e-12
#
# t = 0.10, Ground state energy = -0.751, First excited state energy = -0.264, Gap = 0.487
#
# Sweep =    0 | Direction =  forward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      0.222 | E[  2] =      -5.6823709835     -5.4929965845 | DW = 6.77777e-07
#
# Sweep =    1 | Direction = backward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      0.612 | E[  2] =      -5.8526096398     -5.7053991158 | DE = -2.12e-01 | DW = 3.48768e-07
#
# Sweep =    2 | Direction =  forward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      1.244 | E[  2] =      -5.8607848257     -5.7296016111 | DE = -2.42e-02 | DW = 1.63497e-07
#
# Sweep =    3 | Direction = backward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      1.651 | E[  2] =      -5.8607906790     -5.7297625432 | DE = -1.61e-04 | DW = 1.96388e-07
#
# Sweep =    4 | Direction =  forward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =      2.277 | E[  2] =      -5.8607927340     -5.7297652901 | DE = -2.75e-06 | DW = 9.75954e-09
#
# Sweep =    5 | Direction = backward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =     14.535 | E[  2] =      -5.8607928026     -5.7297654367 | DE = -1.47e-07 | DW = 1.00804e-08
#
# Sweep =    6 | Direction =  forward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =     34.073 | E[  2] =      -5.8607928019     -5.7297654372 | DE = -5.28e-10 | DW = 1.00528e-08
#
# Sweep =    7 | Direction = backward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =     60.592 | E[  2] =      -5.8607928018     -5.7297654369 | DE = 3.57e-10 | DW = 1.00881e-08
#
# Sweep =    8 | Direction =  forward | Bond dimension =   75 | Noise =  0.00e+00 | Dav threshold =  1.00e-09
# Time elapsed =     73.946 | E[  2] =      -5.8607928045     -5.7297654416 | DE = -4.68e-09 | DW = 8.03997e-09
#
# t = 0.20, Ground state energy = -5.861, First excited state energy = -5.730, Gap = 0.131
#
# Sweep =    0 | Direction =  forward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      0.203 | E[  2] =     -15.3292857422    -15.0409702314 | DW = 2.01003e-07
#
# Sweep =    1 | Direction = backward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      0.594 | E[  2] =     -16.0088105796    -15.7032169765 | DE = -6.62e-01 | DW = 4.27897e-07
#
# Sweep =    2 | Direction =  forward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      1.309 | E[  2] =     -16.2526208167    -16.0485180882 | DE = -3.45e-01 | DW = 6.60871e-07
#
# Sweep =    3 | Direction = backward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      2.072 | E[  2] =     -16.2630396696    -16.0882875294 | DE = -3.98e-02 | DW = 4.32753e-07
#
# Sweep =    4 | Direction =  forward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =      2.973 | E[  2] =     -16.2630990021    -16.0889213073 | DE = -6.34e-04 | DW = 3.40513e-08
#
# Sweep =    5 | Direction = backward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =     41.816 | E[  2] =     -16.2630993129    -16.0889222794 | DE = -9.72e-07 | DW = 3.48774e-08
#
# Sweep =    6 | Direction =  forward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =     74.027 | E[  2] =     -16.2630993348    -16.0889224169 | DE = -1.38e-07 | DW = 3.66201e-08
#
# Sweep =    7 | Direction = backward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =     94.409 | E[  2] =     -16.2630993308    -16.0889224223 | DE = -5.38e-09 | DW = 3.66693e-08
#
# Sweep =    8 | Direction =  forward | Bond dimension =   75 | Noise =  0.00e+00 | Dav threshold =  1.00e-09
# Time elapsed =    121.082 | E[  2] =     -16.2630993567    -16.0889224590 | DE = -3.67e-08 | DW = 2.88095e-08
#
# Sweep =    9 | Direction = backward | Bond dimension =   75 | Noise =  0.00e+00 | Dav threshold =  1.00e-09
# Time elapsed =    143.137 | E[  2] =     -16.2630993802    -16.0889224950 | DE = -3.61e-08 | DW = 2.88389e-08
#
# ATTENTION: DMRG is not converged to desired tolerance of 1.00000e-08
# t = 0.30, Ground state energy = -16.263, First excited state energy = -16.089, Gap = 0.174
#
# Sweep =    0 | Direction =  forward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      0.251 | E[  2] =     -29.2883150622    -28.8802692941 | DW = 2.44580e-07
#
# Sweep =    1 | Direction = backward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      0.773 | E[  2] =     -30.5129303988    -30.0713903465 | DE = -1.19e+00 | DW = 3.47565e-06
#
# Sweep =    2 | Direction =  forward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      2.175 | E[  2] =     -30.8625219610    -30.5622592862 | DE = -4.91e-01 | DW = 6.08414e-06
#
# Sweep =    3 | Direction = backward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      3.095 | E[  2] =     -30.8794142642    -30.6215752013 | DE = -5.93e-02 | DW = 1.03045e-06
#
# Sweep =    4 | Direction =  forward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =      4.328 | E[  2] =     -30.8796807774    -30.6238627165 | DE = -2.29e-03 | DW = 6.66915e-08
#
# Sweep =    5 | Direction = backward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =     15.290 | E[  2] =     -30.8796818509    -30.6238655294 | DE = -2.81e-06 | DW = 6.93418e-08
#
# Sweep =    6 | Direction =  forward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =     23.173 | E[  2] =     -30.8796819451    -30.6238657898 | DE = -2.60e-07 | DW = 6.93408e-08
#
# Sweep =    7 | Direction = backward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =     28.206 | E[  2] =     -30.8796819602    -30.6238657818 | DE = 8.04e-09 | DW = 6.92579e-08
#
# Sweep =    8 | Direction =  forward | Bond dimension =   75 | Noise =  0.00e+00 | Dav threshold =  1.00e-09
# Time elapsed =     31.102 | E[  2] =     -30.8796819880    -30.6238658633 | DE = -8.15e-08 | DW = 5.63336e-08
#
# Sweep =    9 | Direction = backward | Bond dimension =   75 | Noise =  0.00e+00 | Dav threshold =  1.00e-09
# Time elapsed =     34.909 | E[  2] =     -30.8796820414    -30.6238659286 | DE = -6.53e-08 | DW = 5.63383e-08
#
# ATTENTION: DMRG is not converged to desired tolerance of 1.00000e-08
# t = 0.40, Ground state energy = -30.880, First excited state energy = -30.624, Gap = 0.256
#
# Sweep =    0 | Direction =  forward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      0.231 | E[  2] =     -47.6579244685    -47.0766166555 | DW = 1.21445e-06
#
# Sweep =    1 | Direction = backward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      0.573 | E[  2] =     -48.9671265153    -48.3372576790 | DE = -1.26e+00 | DW = 3.37418e-06
#
# Sweep =    2 | Direction =  forward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      1.478 | E[  2] =     -49.4135301213    -48.9844773870 | DE = -6.47e-01 | DW = 3.81658e-06
#
# Sweep =    3 | Direction = backward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      2.388 | E[  2] =     -49.4356450754    -49.0759939950 | DE = -9.15e-02 | DW = 1.66894e-06
#
# Sweep =    4 | Direction =  forward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =      3.737 | E[  2] =     -49.4360880343    -49.0795532472 | DE = -3.56e-03 | DW = 9.68860e-08
#
# Sweep =    5 | Direction = backward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =      4.718 | E[  2] =     -49.4360902969    -49.0795580084 | DE = -4.76e-06 | DW = 1.01908e-07
#
# Sweep =    6 | Direction =  forward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =      5.624 | E[  2] =     -49.4360904330    -49.0795584190 | DE = -4.11e-07 | DW = 1.01882e-07
#
# Sweep =    7 | Direction = backward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =      6.640 | E[  2] =     -49.4360904513    -49.0795584059 | DE = 1.31e-08 | DW = 1.02045e-07
#
# Sweep =    8 | Direction =  forward | Bond dimension =   75 | Noise =  0.00e+00 | Dav threshold =  1.00e-09
# Time elapsed =     10.081 | E[  2] =     -49.4360905139    -49.0795584623 | DE = -5.64e-08 | DW = 8.55757e-08
#
# Sweep =    9 | Direction = backward | Bond dimension =   75 | Noise =  0.00e+00 | Dav threshold =  1.00e-09
# Time elapsed =     17.557 | E[  2] =     -49.4360905974    -49.0795585247 | DE = -6.23e-08 | DW = 8.55876e-08
#
# ATTENTION: DMRG is not converged to desired tolerance of 1.00000e-08
# t = 0.50, Ground state energy = -49.436, First excited state energy = -49.080, Gap = 0.357
#
# Sweep =    0 | Direction =  forward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      0.191 | E[  2] =     -68.8935492748    -68.1876309285 | DW = 9.66740e-07
#
# Sweep =    1 | Direction = backward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      0.577 | E[  2] =     -71.1922669498    -70.3116860965 | DE = -2.12e+00 | DW = 1.04814e-05
#
# Sweep =    2 | Direction =  forward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      1.577 | E[  2] =     -71.7965656281    -71.2054935428 | DE = -8.94e-01 | DW = 7.20510e-06
#
# Sweep =    3 | Direction = backward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      2.467 | E[  2] =     -71.8363730367    -71.3532361566 | DE = -1.48e-01 | DW = 2.35835e-06
#
# Sweep =    4 | Direction =  forward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =      3.556 | E[  2] =     -71.8373518001    -71.3612077856 | DE = -7.97e-03 | DW = 1.32407e-07
#
# Sweep =    5 | Direction = backward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =      4.724 | E[  2] =     -71.8373559570    -71.3612191515 | DE = -1.14e-05 | DW = 1.32832e-07
#
# Sweep =    6 | Direction =  forward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =      5.765 | E[  2] =     -71.8373560535    -71.3612204776 | DE = -1.33e-06 | DW = 1.35143e-07
#
# Sweep =    7 | Direction = backward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =      7.110 | E[  2] =     -71.8373561147    -71.3612204998 | DE = -2.22e-08 | DW = 1.35143e-07
#
# Sweep =    8 | Direction =  forward | Bond dimension =   75 | Noise =  0.00e+00 | Dav threshold =  1.00e-09
# Time elapsed =     12.418 | E[  2] =     -71.8373561943    -71.3612205325 | DE = -3.27e-08 | DW = 1.15707e-07
#
# Sweep =    9 | Direction = backward | Bond dimension =   75 | Noise =  0.00e+00 | Dav threshold =  1.00e-09
# Time elapsed =     12.832 | E[  2] =     -71.8373562667    -71.3612205692 | DE = -3.66e-08 | DW = 1.15731e-07
#
# ATTENTION: DMRG is not converged to desired tolerance of 1.00000e-08
# t = 0.60, Ground state energy = -71.837, First excited state energy = -71.361, Gap = 0.476
#
# Sweep =    0 | Direction =  forward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      0.225 | E[  2] =     -93.5960254908    -92.7117119133 | DW = 5.74226e-07
#
# Sweep =    1 | Direction = backward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      0.689 | E[  2] =     -96.6777381503    -95.4939940181 | DE = -2.78e+00 | DW = 1.32585e-05
#
# Sweep =    2 | Direction =  forward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      1.270 | E[  2] =     -97.8364185875    -96.9218065659 | DE = -1.43e+00 | DW = 3.48330e-06
#
# Sweep =    3 | Direction = backward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      1.684 | E[  2] =     -98.0305068840    -97.3639446866 | DE = -4.42e-01 | DW = 3.95067e-06
#
# Sweep =    4 | Direction =  forward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =      2.626 | E[  2] =     -98.0425029916    -97.4269805272 | DE = -6.30e-02 | DW = 2.10958e-07
#
# Sweep =    5 | Direction = backward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =      3.577 | E[  2] =     -98.0425138735    -97.4275955382 | DE = -6.15e-04 | DW = 1.64764e-07
#
# Sweep =    6 | Direction =  forward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =      4.624 | E[  2] =     -98.0425151043    -97.4275997862 | DE = -4.25e-06 | DW = 1.66945e-07
#
# Sweep =    7 | Direction = backward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =      5.704 | E[  2] =     -98.0425152370    -97.4275998871 | DE = -1.01e-07 | DW = 1.65841e-07
#
# Sweep =    8 | Direction =  forward | Bond dimension =   75 | Noise =  0.00e+00 | Dav threshold =  1.00e-09
# Time elapsed =     10.380 | E[  2] =     -98.0425153756    -97.4275999680 | DE = -8.08e-08 | DW = 1.47552e-07
#
# Sweep =    9 | Direction = backward | Bond dimension =   75 | Noise =  0.00e+00 | Dav threshold =  1.00e-09
# Time elapsed =     10.750 | E[  2] =     -98.0425154685    -97.4276000209 | DE = -5.29e-08 | DW = 1.47514e-07
#
# ATTENTION: DMRG is not converged to desired tolerance of 1.00000e-08
# t = 0.70, Ground state energy = -98.043, First excited state energy = -97.428, Gap = 0.615
#
# Sweep =    0 | Direction =  forward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      0.234 | E[  2] =    -122.4353396520   -121.2894441612 | DW = 4.66592e-07
#
# Sweep =    1 | Direction = backward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      0.603 | E[  2] =    -126.2237419218   -124.6786054931 | DE = -3.39e+00 | DW = 2.81887e-05
#
# Sweep =    2 | Direction =  forward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      1.263 | E[  2] =    -127.7465436735   -126.5750062376 | DE = -1.90e+00 | DW = 7.71073e-06
#
# Sweep =    3 | Direction = backward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      1.965 | E[  2] =    -128.0150775818   -127.1603242979 | DE = -5.85e-01 | DW = 3.55360e-06
#
# Sweep =    4 | Direction =  forward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =      3.149 | E[  2] =    -128.0316180086   -127.2577071264 | DE = -9.74e-02 | DW = 2.88291e-07
#
# Sweep =    5 | Direction = backward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =      4.244 | E[  2] =    -128.0316366112   -127.2585792423 | DE = -8.72e-04 | DW = 1.97029e-07
#
# Sweep =    6 | Direction =  forward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =      5.541 | E[  2] =    -128.0316383815   -127.2585882883 | DE = -9.05e-06 | DW = 1.99223e-07
#
# Sweep =    7 | Direction = backward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =      6.510 | E[  2] =    -128.0316382262   -127.2585885803 | DE = -2.92e-07 | DW = 1.99527e-07
#
# Sweep =    8 | Direction =  forward | Bond dimension =   75 | Noise =  0.00e+00 | Dav threshold =  1.00e-09
# Time elapsed =      6.992 | E[  2] =    -128.0316383620   -127.2585886690 | DE = -8.87e-08 | DW = 1.80211e-07
#
# Sweep =    9 | Direction = backward | Bond dimension =   75 | Noise =  0.00e+00 | Dav threshold =  1.00e-09
# Time elapsed =      7.458 | E[  2] =    -128.0316385469   -127.2585887466 | DE = -7.76e-08 | DW = 1.80245e-07
#
# ATTENTION: DMRG is not converged to desired tolerance of 1.00000e-08
# t = 0.80, Ground state energy = -128.032, First excited state energy = -127.259, Gap = 0.773
#
# Sweep =    0 | Direction =  forward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      0.191 | E[  2] =    -154.3589410844   -152.9774548113 | DW = 3.86652e-07
#
# Sweep =    1 | Direction = backward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      0.704 | E[  2] =    -159.5870008855   -157.7025957296 | DE = -4.73e+00 | DW = 1.81575e-05
#
# Sweep =    2 | Direction =  forward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      1.577 | E[  2] =    -161.4355648478   -160.0476816988 | DE = -2.35e+00 | DW = 6.51143e-06
#
# Sweep =    3 | Direction = backward | Bond dimension =   50 | Noise =  1.00e-04 | Dav threshold =  1.00e-10
# Time elapsed =      2.263 | E[  2] =    -161.7661696188   -160.7052508503 | DE = -6.58e-01 | DW = 4.45681e-06
#
# Sweep =    4 | Direction =  forward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =      3.081 | E[  2] =    -161.7941044804   -160.8409298668 | DE = -1.36e-01 | DW = 3.67334e-07
#
# Sweep =    5 | Direction = backward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =      4.169 | E[  2] =    -161.7941355749   -160.8434818701 | DE = -2.55e-03 | DW = 2.25307e-07
#
# Sweep =    6 | Direction =  forward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =      5.058 | E[  2] =    -161.7941420005   -160.8434958177 | DE = -1.39e-05 | DW = 2.29515e-07
#
# Sweep =    7 | Direction = backward | Bond dimension =   75 | Noise =  1.00e-05 | Dav threshold =  1.00e-10
# Time elapsed =      6.105 | E[  2] =    -161.7941419185   -160.8434962438 | DE = -4.26e-07 | DW = 2.29817e-07
#
# Sweep =    8 | Direction =  forward | Bond dimension =   75 | Noise =  0.00e+00 | Dav threshold =  1.00e-09
# Time elapsed =      6.663 | E[  2] =    -161.7941422060   -160.8434962473 | DE = -3.50e-09 | DW = 2.08089e-07
#
# t = 0.90, Ground state energy = -161.794, First excited state energy = -160.843, Gap = 0.951
